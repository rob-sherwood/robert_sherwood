# %% [markdown]
# # Transient Water Release and Imbibitions Method (TRIM) Data Processing Tool

# %% [markdown]
# ## Phase I: Experimental setup.
# ___

# %% [markdown]
# <img src="PhaseI.png" alt="PhaseI" width="500"/>
# Figure 1.1: Diagram of the TRIM experiment (Wallayce and Lu 2012); focus of Phase I: design a sample to be tested in the TRIM.
#
# ___
# <img src="small cell.jpg" alt="small cell" width="200"/>
# Figure 1.2: Small cell for testing earthen materials mith a max nominal partile size not greater than 1 cm (~0.39 inch).
#
# ___
# <img src="large cell.jpg" alt="large cell" width="200"/>
# Figure 1.3: Large cell for testing earthen materials with a max nominal particle size not greater than 4.25 cm (~1.67 inch).

# %%
import numpy as np

# %%
# Allows the user to select which TRIM cell will be used.
Cell = input("Specify which cell you will be using; spell in all lower case letters (e.g., small or large):")

# Selects the appropriate sell dimensions based on the sell name: small or large.
if Cell == 'small':
    D_cell = 6.175   # [cm]
    H_cell = 6.597   # [cm]
else:
    D_cell = 25.50   # [cm]
    H_cell = 17.80   # [cm]

# Calculates the cross section area of the flow cell (A_cell in cm^2).
A_cell = np.pi * D_cell **2 /4   # [cm^2]    

#............................................................................................................

# User Input Sample Information: 
## mass of dry solids (Ms in gr.), 
## specific gravity of solids (Gs), and 
## target dry density of sample (rho_d in gr./cm^3). 
Ms = float(input("Insert the mass of dry solids in gr. (e.g., 170.00):"))
Gs = float(input("Insert the specific gravity of solids (e.g., 2.70):"))
rho_dry = float(input("Insert the target dry density of the sample in gr./cm^3 (e.g., 1.69):"))

# Calculating the design height (H in cm) required to meet target dry density.
H = Ms / rho_dry / A_cell   # [cm]
H_from_top = H_cell - H     # [cm]

# Brief report of sample design information; gives the user an opportunity to construct the sample 
# before moving to the next step.
print("\nCompact the", Ms, "gr. of dry material to a height of", round(H,2), 
      "[cm] (i.e.", round(H_from_top,2), "cm from the top of the \nacrylic housing).")
print("\nAfter compaction, take three depth measurements between the top of the acrylic housing and",
      "the sample \nsurface; measure in cm. Those measurements will be used to calculate the actual",
      "sample dry density \n(gr./cm^3), porosity, and the mass of water required to saturate the",
      "sample (gr.). \n")

# Gives the user control over progression to the next step.
Next_step = input("When you have your depth measurements ready, press Enter:")

# User input: three measurements of the depth to the sample surface (Dpth# in cm).
print("\nInsert the three sample height measurements in cm.")
Dpth1 = float(input("Actual depth #1 (e.g., 3.26):"))   # [cm]
Dpth2 = float(input("Actual depth #2 (e.g., 3.24):"))   # [cm]
Dpth3 = float(input("Actual depth #3 (e.g., 3.22):"))   # [cm]

# Calculates the average sample height in cm.
H_avg = H_cell - np.average([Dpth1, Dpth2, Dpth3])   # [cm]

# Defining the density of water at 20C.
rho_w = 0.9982   # [gr./cm^3]

# Calculates the porosity of the sample (n) and the mass of water required to saturate the sample (Mw in gr.)
# based on the average measured sample height.
n = 1 - (Ms / (Gs * H_avg * A_cell))    # [no units]
Mw = H_avg * A_cell * rho_w - Ms / Gs   # [gr.]

#............................................................................................................

# Creating and reporting important sample design information to a .txt file for convenient storage.
fh = open("Sample_Design.txt", "w")
fh.writelines(["Summary of Experimental Setup \n TRIM cell info... \n \t Cell type = ", Cell, "\n \t",
               "Diameter = ", str(D_cell), " [cm] \n \t Height = ", str(H_cell), " [cm]",
               "\n Soil sample info... \n \t Total Dry Mass (Ms) = ", str(Ms), " [gr.] \n \t",
               "Specific Gravity (Gs) = ", str(round(Gs,2)), " [gr./gr.] \n \t Height (H) = ", 
               str(round(H_avg,2)), " [cm] \n \t Dry Density (rho) = ", str(round(rho_dry,2)), 
               " [gr./cm^3] \n \t Porosity (n) = ", str(round(n,3)), "\n \t Mass of H2O to Saturate",
               "(Mw) = ", str(round(Mw,2)), " [gr.]"])
fh.close()

# Giving an in-Python display of what was exported to the .txt file.
print("\nThe following is a summary of experimental setup information. It was transferred to the",
      "\n'Sample_Design.txt' file. \n\n Summary of Experimental Setup \n TRIM cell info... \n\t Cell type = ", 
      Cell, "\n\t Diameter =", D_cell, "[cm] \n\t Height =", H_cell, "[cm] \n Soil sample info... \n\t", 
      "Total Dry Mass (Ms) =", Ms, "[gr.] \n\t Specific Gravity (Gs) =", round(Gs,2), "[gr./gr.] \n\t",
      "Height (H) =", round(H_avg,2), "[cm] \n\t Dry Density (rho_dry) =", round(rho_dry,2), 
      "[gr./cm^3] \n\t Porosity (n) =", round(n,3), "\n\t Mass of H2O to Saturate (Mw) =", round(Mw,2), 
      "[gr.]")
# Out:
# Specify which cell you will be using; spell in all lower case letters (e.g., small or large): small
# Insert the mass of dry solids in gr. (e.g., 170.00): 170.00
# Insert the specific gravity of solids (e.g., 2.70): 2.70
# Insert the target dry density of the sample in gr./cm^3 (e.g., 1.69): 1.69
# Compact the 170.0 gr. of dry material to a height of 3.36 [cm] (i.e. 3.24 cm from the top of the
# acrylic housing).
#
# After compaction, take three depth measurements between the top of the acrylic housing and the sample
# surface; measure in cm. Those measurements will be used to calculate the actual sample dry density
# (gr./cm^3), porosity, and the mass of water required to saturate the sample (gr.).
# When you have your depth measurements ready, press Enter:
# Insert the three sample height measurements in cm.
# Actual depth #1 (e.g., 3.26): 3.26
# Actual depth #2 (e.g., 3.24): 3.24
# Actual depth #3 (e.g., 3.22): 3.22
# ...

# %% [markdown]
# ___

# %% [markdown]
# ## Phase II: Processing raw TRIM data; preparation of inputs for Hydrus ID model use.
# ___

# %% [markdown]
# <img src="PhaseII.png" alt="PhaseII" width="500"/>
# Figure 2.1: Diagram of the TRIM experiment (Wallayce and Lu 2012); focus of Phase II: correcting and sampling transient outflow data from the TRIM experiment in preparation for inverse modeling.
#
# ___
# <img src="Raw and Sampled TRIM Data.png" alt="Raw and Sampled TRIM Data" width="500"/>
# Figure 2.2: Example of the raw data from the TRIM experiment next to the processed data (ouput of this code) ready to be input to Hydrus sofware.

# %%
import pandas as pd
import numpy as np
import re
import matplotlib.pyplot as plt
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()

# %%
#Defining functions needed of data processing.

def sample_pts2(points, max_time_step, max_points):

    """This function samples points form the outflow data. 
    It samples less points where the plot of the data is flat and more points where the 
    plot of the data is curved. Points are selected based on a time step and a mass step."""
    
    # Pre-allocating list to store data selected data points in.
    chosen_pts = []

    # Specifying the starting place for point to point comparison (point 'a' to point 'b').
    # Also adding the first point (point a) to the pre-allocated list 'chosen'.
    a = np.min(points)
    b = a + 1
    chosen_pts.append(a)
    
    # Creates short-hand variables for a shorter code. The long-had names are used in the definition line 
    # to provide more clear explanation.
    mx_ts = max_time_step
    mx_ps = max_points

    # Finds the max and minimum in the list of points.
    top = np.max(points)
    bottom = np.min(points)

    # For loop to execute point to point comparison while changing the step distances to accommodate for 
    # curvature of the plot and sampling rates of the data.
    for count in range(len(points)):
        if (df.Delta_sec[b] - df.Delta_sec[a]) <= mx_ts or (df['Mass (g)'][b] - df['Mass (g)'][a]) < (df['Mass (g)'][top] - df['Mass (g)'][bottom]) / mx_ps:
            b = b + 1   # Increases the step by an increment of 1 (one) to when the time step or mass step 
                        # are smaller than desired.
        else:
            #while (df['Mass (g)'][b] - df['Mass (g)'][a])/(df.Delta_sec[b] - df.Delta_sec[a])/3600 > 
            #0.01 # [gr./hr]
            chosen_pts.append(b)   # Collects the desired points.
            a = b              # Updating the point of comparison to the selected point.
            b = b + 1          # Stepping forward one point to initiate selection of the next point.
    
    # Returning a data frame of the selected points.
    return(pd.DataFrame({'chosen_pts': chosen_pts}))

# %%
## Extracting raw TRIM data from the text file output of the TRIM program.
## Reading raw evaporation data.
fh_raw = input("Please specify the raw data file name; the name must contain '.txt' (e.g., Valley Sub raw.txt):")
fh = open((str(fh_raw)), 'r')
fh = fh.read()
fh = re.sub('\t\t', '\t', fh)
fh = fh.split('\n')

for i in range(len(fh)):
    fh[i] = fh[i].split('\t')

df = pd.DataFrame(fh)

print("\nThe minimum number of sampled TRIM data points for inversion modeling is 100 pints.")
Nom_sampled_pts = float(input("Please specify the number of data points you wish to sample from the raw TRIM data set (e.g., 150):"))

## Establishing the column titles using the existing titles printed by Hydrus 1D.
for i in range(0,6):
    df[df[i][0]] = df[i]
    df = df.drop(columns = [i])

df = df[1: len(df)-2]
df = df.reset_index(0)
df = df.drop(columns = ["Notes", "index"])

for j in range(len(df)):
    df['Mass (g)'][j] = float(df['Mass (g)'][j])       # [gr.]
    df['Uair (kPa)'][j] = float(df['Uair (kPa)'][j])   # [kPa]
    
## Converting time from [[YYYY/MM/DD], [HH:MM AM/PM]] to [sec] for calculations and plotting.
df['Datetime'] = pd.to_datetime(df.Date + " " + df.Time)   # from [[MM/DD/YYYY], [HH:MM, AM/PM]] to [YYYY/MM/DD, HH:MM:SS].
df['Time_diff']= df.Datetime - df.Datetime[0]              # from [YYYY/MM/DD, HH:MM:SS] to [days, HH:MM:SS].
df['Delta_sec']= df.Time_diff.dt.days * 86400 + df.Time_diff.dt.seconds   # from [days, HH:MM:SS] to [sec].

## Storing raw data for comparison to processed data.
Raw_Mass = df['Mass (g)']
Raw_Time = df['Delta_sec']

#............................................................................................................

# Sort data based on step type: 'Before Test', 'small increment', and 'Large increment'.

## Removing 'Before Test' data.
idx = df.Step != "Before Test"      # Identifies the rows to keep: 'small' and 'Large increments'
df = df[idx]                        # Applies the index to the data frame removing the 'Before Test' data.
df = df.reset_index(0)              # Resets the index to zero.
df = df.drop(columns = ['index'])   # Drops the old index column.

## Pre-allocate lists to store appropriate index values.
sm_inc_idx = []
lg_inc_idx = []

## Using a for loop to sort index values based on step: 'small increment' and 'Large increment'.
for index in range(len(df.Step)):    
    if df.Step[index] == "small increment":
        sm_inc_idx.append(index)
    else:
        lg_inc_idx.append(index)

#............................................................................................................

# Calculating the rate of diffused air, and correcting the large increment data for diffused air.

## User input Bubble Trap measurement, in mL.
bub_trap = float(input("\nInput the amount of air measured in the bubble trap, in mL (e.g., 2.7):"))   # [mL]

## Calculate the mass of water released during the Large increment, in grams. 
H2O_out = float(df['Mass (g)'][np.max(lg_inc_idx)])   # [gr.]

## Calculate the rate of diffused air during the Large increment.
rt_diff_air = bub_trap / H2O_out #lg_inc   # [ml air / total grams H2O out] = [gr./gr.], rho_H2O=1.0 gr/ml
print("\nThe rate of diffused air is:", round(rt_diff_air,2), "gr./gr.")

#............................................................................................................   

# Correcting all mass measurements for evaporation and for oversaturation.

# Retrieving sample specifications from the sample design sheet: sample height (H_sample) [cm],
# sample diameter (D_sample) [cm], and porosity (n).

## Opening the text file.
fh_SD = open("Sample_Design.txt", "r")
fh_SD = fh_SD.read()

## Segragating the text into managable strings.
fh_SD = re.sub(' \t ', '', fh_SD)
fh_SD = fh_SD.split('\n')
fh_SD = pd.DataFrame(fh_SD)

##  Extracting the values of required_water [gr.].
required_water = fh_SD[0][11]; required_water = required_water.split(' ')
required_water = float(required_water[6])

## User inputs the mass of water required to saturate the sample and the amount that was in the sample
##when the test was initiated.
imbibed_water = float(input("\nInput the mass of water imbibed into the sampe, in gr. (e.g., 37.40):"))   # [gr.]
print(" ") # Making some space for readability of printed information.

## Equation: Correct_Mass1[gr.] = Mass1[gr.] + Cumulative_time[sec] * Evap_rate[gr./sec]
evap_rate = 0.0927/86400                                      # [gr./sec], Evaporation rate is constant.
excess_water = imbibed_water - required_water                 # [gr.]
df['Mass (g)'] = df['Mass (g)'] + df.Delta_sec * evap_rate - excess_water   # [gr.]

## Updating the 'Mass (g)' column with the corrected values, and removing the rows with negative mass values.
idx = df['Mass (g)'] > 0                                     # Boolean index to indicate negative mass values.
df = df[idx]                                                 # selecting rows that have positive mass values.
df = df.reset_index(0)                                       # Resetting the index to start with zero.
df = df.drop(columns = ['index', 'Datetime', 'Time_diff'])   # Removing extra columns.

#............................................................................................................

# Sampling data from the corrected TRIM data.

## Overwrite the 'small increment', and 'Large increment' indexes as empty lists.
sm_inc_idx = []
lg_inc_idx = []

## Using a for loop to sort index values based on step: 'small increment' and 'Large increment'.
for index in range(len(df.Step)):    
    if df.Step[index] == "small increment":
        sm_inc_idx.append(index)
    else:
        lg_inc_idx.append(index)

# Sampling data from the corrected TRIM data.

## Specifying the initial step size for time (mx_ts) and mass (mx_ps).
mx_ts = 300   # Not to exceed the max. sampling rate used to collect the TRIM experiment data, ~ 300 seconds.
mx_ps = 100   # Not to be less than the min. points for inverse modeling: 100 points, (Wayllace and Lu 2012).

## Executing the sampling function for the small and the large step increments of the TRIM test individually,
## then combining the two data frames into one.
chosen_sm = sample_pts2(range(np.min(sm_inc_idx),np.max(sm_inc_idx)),mx_ts,mx_ps)
chosen_lg = sample_pts2(range(np.min(lg_inc_idx),np.max(lg_inc_idx)),mx_ts,mx_ps)
df3 = chosen_sm.append(chosen_lg)

## Optimizing the step size to meet or slightly exceed the minimum number of points for modeling. 
## The minimum number of point required is 100.
while len(df3) < Nom_sampled_pts:
    
    df3 = []   # Emptying the data frame
    
    ## Adjusting the step sizes
    mx_ts = mx_ts - 25
    mx_ps = mx_ps + 25
    
    ## Re-sampling using the adjusted step sizes and merging the two data frames into one.
    chosen_sm = sample_pts2(range(np.min(sm_inc_idx),np.max(sm_inc_idx)),mx_ts,mx_ps)
    chosen_lg = sample_pts2(range(np.min(lg_inc_idx),np.max(lg_inc_idx)),mx_ts,mx_ps)
    df3 = chosen_sm.append(chosen_lg)

#............................................................................................................ 

# Plotting the selected points to show the sampled data.
plt.figure(figsize = (10,5))
plt.subplot(1,2,1)
plt.scatter(Raw_Time, Raw_Mass, alpha = 0.5, label="Raw Data", color = "green")
plt.title("$Raw\ Outflow\ Data$", fontsize = 16)
plt.ylabel("$Mass\ H_2O\ Out\ (gr.)$", fontsize = 14)
plt.xlabel("$Time\ (sec)$", fontsize = 14)
plt.xticks(rotation = 20)
plt.legend(loc = 4) # Positions legend in the lower right corner.

plt.subplot(1,2,2)
plt.scatter(df.Delta_sec.reindex(df3.chosen_pts), df['Mass (g)'].reindex(df3.chosen_pts), 
            alpha = 0.5, label="Sampled Points", color = "green")
plt.title("$Sampled\ Outflow\ Data$", fontsize = 16)
plt.ylabel("$Mass\ H_2O\ Out\ (gr.)$", fontsize = 14)
plt.xlabel("$Time\ (sec)$", fontsize = 14)
plt.xticks(rotation = 20)
plt.legend(loc = 4) # Positions legend in the lower right corner.
plt.tight_layout()
plt.savefig("Raw and Sampled TRIM Data")
plt.show()

## Plot caption...
print("Figure 1: plot of sampled outflow data; data are corrected for evaporation, and saturation error.")

#............................................................................................................

# Exporting the sampled points as tab delimited text file: TRIM_input.txt.

## Create a data frame to store all the information that are to be exported.
TRIM_input = pd.DataFrame()

## Add all the appropriate data to that data frame: data are selected using the sampled points as an index 
## so that the corresponding data for each selected point is collected.
TRIM_input['Date'] = df.Date[df3.chosen_pts]                          # [MM/DD/YYYY]
TRIM_input['Time'] = df.Time[df3.chosen_pts]                          # [HH:MM:SS AM/PM]
TRIM_input['Step'] = df.Step[df3.chosen_pts]                          # [small increment or Large increment]
TRIM_input['Mass (g)'] = df['Mass (g)'].reindex(df3.chosen_pts)       # [gr.]
TRIM_input['Uair (kPa)'] = df['Uair (kPa)'].reindex(df3.chosen_pts)   # [kPa]

## Sets the 'Date' column as the data frame index.
TRIM_input = TRIM_input.set_index('Date')

## Export the data frame as a tab delimited text file. The format is selected to be accepted by Hydrus 1D.
TRIM_input.to_csv("TRIM_input.txt", sep = "\t")

## Notify the user that the data has been exported to the txt file.
print("\nThe sampled outflow data in Figure 1 were exported to a tab delimited text file: 'TRIM_input.txt'")

print("\nThe 'TRIM_input.txt' file is formatted to be accepted as-is by Hydrus 1D software as TRIM input data; \n",
     "however, the 'TRIM_intpu.txt' file must be accompanied by the 'TRIM parameters.txt' file which \n",
     "you must update manually. A template file is attached.\n")
# Out:
# Please specify the raw data file name; the name must contain '.txt' (e.g., Valley Sub raw.txt): Valley Sub raw.txt
# The minimum number of sampled TRIM data points for inversion modeling is 100 pints.
# Please specify the number of data points you wish to sample from the raw TRIM data set (e.g., 150): 150
#
# Input the amount of air measured in the bubble trap, in mL (e.g., 2.7): 2.7
# The rate of diffused air is: 0.11 gr./gr.
# Input the mass of water imbibed into the sampe, in gr. (e.g., 37.40): 37.4
# Figure 1: plot of sampled outflow data; data are corrected for evaporation, and saturation error.
#
# The sampled outflow data in Figure 1 were exported to a tab delimited text file: 'TRIM_input.txt'
#
# The 'TRIM_input.txt' file is formatted to be accepted as-is by Hydrus 1D software as TRIM input data;
#  however, the 'TRIM_intpu.txt' file must be accompanied by the 'TRIM parameters.txt' file which
#  you must update manually. A template file is attached.

# %%
# Show the exported/sampled TRIM data which will be used for inverse modleing of the SWCC and HCF.
pd.read_csv("TRIM_input.txt", sep = "\t")
# Out:
#           Date         Time             Step   Mass (g)  Uair (kPa)
# 0    7/24/2019   9:21:02 AM  small increment   0.000107         4.0
# 1    7/24/2019   9:23:12 AM  small increment   0.030247         4.0
# 2    7/24/2019   9:25:23 AM  small increment   0.050387         4.0
# 3    7/24/2019   9:27:33 AM  small increment   0.080527         4.0
# 4    7/24/2019   9:29:43 AM  small increment   0.100666         4.0
# ..         ...          ...              ...        ...         ...
# 151  7/25/2019   8:21:29 PM  Large increment  24.845324       290.0
# 152  7/25/2019  10:46:31 PM  Large increment  24.934660       290.0
# 153  7/26/2019   1:06:34 AM  Large increment  25.023676       290.0
# 154  7/26/2019   3:16:37 AM  Large increment  25.112048       290.0
# 155  7/26/2019   3:51:38 AM  Large increment  25.204302       290.0
#
# [156 rows x 5 columns]

# %% [markdown]
# ___

# %% [markdown]
# ## Phase III: Plotting the objective function, SWCC, and HCF from Hydrus 1D output.
# ___

# %% [markdown]
# <img src="PhaseIII.png" alt="PhaseIII" width="500"/>
# Figure 3.1: Diagram of the TRIM experiment (Wallayce and Lu 2012); focus of Phase III: plotting results of the inverse modeling portion of the TRIM.
#
# ___
# <img src="TRIM Results.png" alt="TRIM Results" width="500"/>
# Figure 3.2: Example of the plots produced by this code: Hydrus ID corrected and fitted Objective Funciton, and the van Genuchten (1980) Soil Water Characteristic Curve and Hydraulic Conductivity Function which were modeled using Hydrus 1D and an inverse method.

# %%
import re
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()

# %%
# Opening the data Hydrus 1D output file (Fit.out) and formatting the information to make it 
# readable and separable.

## User specifies the path to the outfile.
fh_Hydrus_1D = input("Please specify the path to Hydrus 1D results; the file must be the '\Fit.out' file (e.g., VS_cor-for-diff-air\Fit.out):")

## Opening the .out file. Segregating the main text into idealized groups (strings) for easy access and manipulation.
fh = open((str(fh_Hydrus_1D)), 'r')
fh = fh.read()
fh = re.split("\n\n\n", fh)

## Compensating for some of the omitted parameter lines in Hydrus output. 
## This enables the code to run using two formats of Hydrus 1D output.
if len(fh) == 12:
    Param_data = 5
    Regression_data = 8
    Fit_data = 9
    SWCC_data = 10
elif len(fh) == 13:
    Param_data = 5
    Regression_data = 8
    Fit_data = 10
    SWCC_data = 11
else:
    print("Error: Please allow Hydrus 1D to optimize WCR, ALPHA, N, and COND when modeling; this code is not",
          "prepared to navigate Hydrus output files where these parameters are not optimized.")
#.............................................................................................................

# Handling of estimated parameters - sum of squared error (SSQ) and van Genuchten fitting parameters: 
# residual water content (WCR), air entry (ALPHA)[1/cm], pore size distribution coefficient (N),
# and saturated hydraulic conductivity (COND)[cm/s].

## Accessing the estimated parameters from the main text file. ## Formatting strings to be converted into a DataFrame.
fh_fit_params = fh[Param_data]
fh_fit_params = re.split('\n', fh_fit_params)   

for i in range(len(fh_fit_params)):        
    fh_fit_params[i] = re.sub('SSQ', '  SSQ', fh_fit_params[i])
    fh_fit_params[i] = re.sub('      ', ' ', fh_fit_params[i])
    fh_fit_params[i] = re.sub('     ', ' ', fh_fit_params[i])
    fh_fit_params[i] = re.sub('    ', '  ', fh_fit_params[i])
    fh_fit_params[i] = re.sub('D+','E', fh_fit_params[i])           # Change scientific notation format from D+00 to E+00
    fh_fit_params[i] = re.sub('CONES ', 'K_sat', fh_fit_params[i])  
    fh_fit_params[i] = re.split('  ', fh_fit_params[i])
        
## Putting data into a DataFrame: df_fit_params.
df_fit_params = pd.DataFrame(fh_fit_params)
df_fit_params = df_fit_params[4:]

## Establishing the column titles using the existing titles printed by Hydrus 1D.
for i in range(6):
    df_fit_params[df_fit_params[i][4]] = df_fit_params[i]
    df_fit_params = df_fit_params.drop(columns = [i])

## Dropping unnecessary rows and columns, and resetting the index to start from zero.
df_fit_params = df_fit_params[1:]
df_fit_params = df_fit_params.reset_index(0)
df_fit_params = df_fit_params.drop(columns = ['index'])

## Storing final values in the original scientific notation.
SSQ = ("$SSQ$    =" + df_fit_params.SSQ[len(df_fit_params.SSQ)-1])
ALPHA = ("$\u03B1$  = " + df_fit_params.ALPHA[len(df_fit_params.ALPHA)-1])   # \u03B1 is Unicode for alpha.
K_SAT = ("$K_s$ = " + df_fit_params.K_sat[len(df_fit_params.K_sat)-1])

## Converting all DataFrame info from type string to type float for plotting and potential calculations.
for j in range(len(df_fit_params)):
    df_fit_params['SSQ'][j] = float(df_fit_params['SSQ'][j])       # -           Sum of Squared Error
    df_fit_params['WCR'][j] = float(df_fit_params['WCR'][j])       # [cm^3/cm^3] Residual Volumetric Water Content
    df_fit_params['ALPHA'][j] = float(df_fit_params['ALPHA'][j])   # [1/cm]      Fitting Parameter: ~Inverse of Air Entry
    df_fit_params['N'][j] = float(df_fit_params['N'][j])           # -           Fitting Parameter: ~Pore Size Distribution
    df_fit_params['K_sat'][j] = float(df_fit_params['K_sat'][j])   # [cm/s]      Saturated Hydraulic Conductivity
    
WCR = ("$\u03B8_r$ = " + str(round(df_fit_params.WCR[len(df_fit_params.WCR)-1],3)))   # \u03B8 is unicode for theta.
N = ("$n$  = " + str(round(df_fit_params.N[len(df_fit_params.N)-1],3)))

#.............................................................................................................

# Handling of Fit statistics: Regression coefficient (R^2) and root mean square error (RMSE).

## Accessing the fit statistics from the main text file.
fh_fit_stats = fh[Regression_data]

## Formatting strings to be converted into a DataFrame.
fh_fit_stats = re.sub("\n\n", "\t\t", fh_fit_stats)
fh_fit_stats = re.sub("\n", "\t\t", fh_fit_stats)
fh_fit_stats = re.split("\t\t ", fh_fit_stats)

## Collecting R^2 and RMSE values.
R_2 = fh_fit_stats[2]
R_2 = re.split("=", R_2)
R_2_value = "$R^2$      = " + (R_2[1])

RMSE = fh_fit_stats[5]
RMSE = re.split(":  ", RMSE)
RMSE_value = "$RMSE$ = " + (RMSE[1])

#.............................................................................................................

# Handling of observed (Obs) and calculated (Fitted) transient outflow data, from TRIM experiment and
# numerical solution of Richards' equation, respectively.

## Accessing the observed and calculated outflow data from the main text file.
fh_fit = fh[Fit_data]

## Formatting strings to be converted into a DataFrame.
fh_fit = re.split('\n', fh_fit)

for i in range(len(fh_fit)):        
    fh_fit[i] = re.sub('      ', ' ', fh_fit[i])
    fh_fit[i] = re.sub('     ', '  ', fh_fit[i])
    fh_fit[i] = re.sub('    ', '  ', fh_fit[i])
    fh_fit[i] = re.sub('   ','  ', fh_fit[i])
    fh_fit[i] = re.sub('  ', ' ', fh_fit[i])
    fh_fit[i] = re.sub('dual', 'Residual', fh_fit[i])
    fh_fit[i] = re.split(' ', fh_fit[i])

## Putting data into a DataFrame: df_fit.
df_fit = pd.DataFrame(fh_fit)
df_fit = df_fit[3:]
str(df_fit[3])

## Establishing the column titles using the existing titles printed by Hydrus 1D.
for i in range(8):
    df_fit[df_fit[i][3]] = df_fit[i]
    df_fit = df_fit.drop(columns = [i])

## Dropping unnecessary rows and columns, and resetting the index to start from zero.
df_fit = df_fit[1:]
df_fit = df_fit.reset_index(0)
df_fit = df_fit.drop(columns = ['index'])#, 'No'])

## Converting all DataFrame info from type string to type float for plotting and potential calculations.
for j in range(len(df_fit)):
    df_fit['Time'][j] = float(df_fit['Time'][j])           # [sec]       Time
    df_fit['Obs'][j] = float(df_fit['Obs'][j])             # [cm^3/cm^2] Volume H2O out of sample/cell cross section area
    df_fit['Fitted'][j] = float(df_fit['Fitted'][j])       # [cm^3/cm^2] Volume H2O out of sample/cell cross section area
    df_fit['Residual'][j] = float(df_fit['Residual'][j])   # [unitless]  Residual between Obs and Fitted
    df_fit['Type'][j] = float(df_fit['Type'][j])           # -           -
    df_fit['Position'][j] = float(df_fit['Position'][j])   # -           -
    
# Converting the Obs and Fitted data to transient volumetric water content of sample and cumulative water out.
## Need to retrieve sample specifications from the sample design text file: sample height (H_sample) [cm],
## sample diameter (D_sample) [cm], and porosity (n).

## Opening the text file.
fh_SD = open("Sample_Design.txt", "r")
fh_SD = fh_SD.read()

## Segregating the text into manageable strings.
fh_SD = re.sub(' \t ', '', fh_SD)
fh_SD = fh_SD.split('\n')
fh_SD = pd.DataFrame(fh_SD)

## Extracting the values of H_sample [cm], D_sample [cm], and porosity.
Height = fh_SD[0][8]; Height = Height.split(' '); H_sample = float(Height[3])            # [cm]
Diameter = fh_SD[0][3]; Diameter = Diameter.split(' '); D_sample = float(Diameter[2])    # [cm]
Porosity = fh_SD[0][10]; Porosity = Porosity.split(' '); porosity = float(Porosity[3])   # -    

## Calculating the cross-section area and volume of the test specimen: needed for conversions.
A_sample = np.pi * D_sample**2 / 4   # [cm^2] Sample cross section area
V_sample = A_sample * H_sample       # [cm^3] Sample volume

## Unit conversions: [cm^3/cm^2] Volume H2O out/cell cross section area to [cm^3/cm^3] Volumetric Water Content,
## and time [sec] to time [days].
#df_fit.Obs = (df_fit.Obs * A_sample + porosity*100) / V_sample         # [cm^3/cm^3] Volumetric Water Content of sample
#df_fit.Fitted = (df_fit.Fitted * A_sample + porosity*100) / V_sample   # [cm^3/cm^3] Volumetric Water Content of sample
df_fit.Obs = abs(df_fit.Obs * A_sample)         # [gr. H2O] Mass Water out of sample
df_fit.Fitted = abs(df_fit.Fitted * A_sample)   # [gr. H2O] Mass Water out of sample
df_fit.Time = df_fit.Time / 86400               # [days]      Convert sec. to days

#.............................................................................................................

# Handling of SWCC data: matric suction (Pressure, log P) [cm H2O], volumetric water content (WC) [cm^3/cm^3],
# and variations of unsaturated hydraulic conductivity (Rel K, log RK, Abs K, log KA) [cm/s] and diffused air
# (Diffus, log D)

## Accessing the SWCC data from the main text file.
fh_SWCC_soil = fh[SWCC_data]

## Formatting strings to be converted into a DataFrame.
fh_SWCC_soil = re.split("\n", fh_SWCC_soil)

for i in range(len(fh_SWCC_soil)):        
    fh_SWCC_soil[i] = re.sub('     ', '  ', fh_SWCC_soil[i])
    fh_SWCC_soil[i] = re.sub('    ', '  ', fh_SWCC_soil[i])
    fh_SWCC_soil[i] = re.sub('   ', '  ', fh_SWCC_soil[i])
    fh_SWCC_soil[i] = re.sub('  ', '  ', fh_SWCC_soil[i])
    if i == 0:
        fh_SWCC_soil[i] = re.split('  ', fh_SWCC_soil[i])
    else:
        fh_SWCC_soil[i] = re.sub('  ', ' ', fh_SWCC_soil[i])
        fh_SWCC_soil[i] = re.split(' ', fh_SWCC_soil[i])

## Putting data into a DataFrame: df_SWCC_soil.
df_SWCC_soil = pd.DataFrame(fh_SWCC_soil)

## Establishing the column titles using the existing titles printed by Hydrus 1D.
for i in range(9):
    df_SWCC_soil[df_SWCC_soil[i+1][0]] = df_SWCC_soil[i+1][1:len(df_SWCC_soil)]
    df_SWCC_soil = df_SWCC_soil.drop(columns = [i+1])

## Converting the type 'NoneType' in these rows to type string.
df_SWCC_soil['Log KA'][1] = str(df_SWCC_soil['Log KA'][1])
df_SWCC_soil['Diffus'][1] = str(df_SWCC_soil['Diffus'][1])
df_SWCC_soil['Log D'][1] = str(df_SWCC_soil['Log D'][1])

## Replacing missing data with numpy NaN (including the 'NoneType' data which was converted to type 'string').
idx_missing = df_SWCC_soil.isin(['', 'None'])
df_SWCC_soil[idx_missing] = np.nan

## Dropping unnecessary rows and columns, and resetting the index to start from zero.
df_SWCC_soil = df_SWCC_soil[1:len(df_SWCC_soil)]
df_SWCC_soil = df_SWCC_soil.reset_index(0)
df_SWCC_soil = df_SWCC_soil.drop(columns = ['index'])

## Converting all DataFrame info from type string to type float for plotting and potential calculations.
for j in range(len(df_SWCC_soil)):
    df_SWCC_soil['Pressure'][j] = float(df_SWCC_soil['Pressure'][j])   # [cm H2O]        Matric Suction
    df_SWCC_soil['Log P'][j] = float(df_SWCC_soil['Log P'][j])         # [log cm H20]    -
    df_SWCC_soil['WC'][j] = float(df_SWCC_soil['WC'][j])               # [cm^3/cm^3]     Volumetric Water Content
    df_SWCC_soil['Rel K'][j] = float(df_SWCC_soil['Rel K'][j])         # [cm/s]          Unsaturated Hydraulic Conductivity (UHC)
    df_SWCC_soil['Log RK'][j] = float(df_SWCC_soil['Log RK'][j])       # [log cm/s]      -
    df_SWCC_soil['Abs K'][j] = float(df_SWCC_soil['Abs K'][j])         # [abs cm/s]      Absolute Value UHC
    df_SWCC_soil['Log KA'][j] = float(df_SWCC_soil['Log KA'][j])       # [log abs cm/s]  -
    df_SWCC_soil['Diffus'][j] = float(df_SWCC_soil['Diffus'][j])       # [cm^3/cm^3]     Diffused Air
    df_SWCC_soil['Log D'][j] = float(df_SWCC_soil['Log D'][j])         # [log cm^3/cm^3] -
    
#.............................................................................................................

# Read the csv file to check for mistakes.
df2 = pd.read_csv("TRIM_input.txt", sep = "\t")

## Converting time from [[YYYY/MM/DD], [HH:MM AM/PM]] to [sec] for calculations and plotting.
df2['Datetime'] = pd.to_datetime(df2.Date + " " + df2.Time)                # from [[MM/DD/YYYY], [HH:MM, AM/PM]] to [YYYY/MM/DD, HH:MM:SS].
df2['Time_diff']= df2.Datetime - df2.Datetime[0]                           # from [YYYY/MM/DD, HH:MM:SS] to [days, HH:MM:SS].
df2['Delta_sec']= df2.Time_diff.dt.days + df2.Time_diff.dt.seconds/86400   # from [days, HH:MM:SS] to [decimal days].

#.............................................................................................................
                 
# Plotting the objective function (observed and fitted curves), and the soil water characteristic curve 
# (SWCC) with the hydraulic conductivity function (HCF).

plt.figure(figsize = (10,5))

## Plotting of the objective function: observed volumetric water content (Obs) [cm^3/cm^3], and 
## fitted volumetric water content (Fitted) [cm^3/cm^3] vs. Time [days] with statistics: R^2, RMSE, and SSQ.
plt.subplot(1,2,1)
plt.plot(df_fit.Time, df_fit.Obs, ':r', label = "$Observed$", alpha = 0.9)
plt.plot(df_fit.Time, df_fit.Fitted, ':k', label = "$Fitted$", alpha = 0.6)
plt.plot(df2['Delta_sec'], df2['Mass (g)'], 'g', label = "$Sampled$", alpha = 0.4)
plt.title("$Objective\ Function$", fontsize = 16)
plt.xticks(rotation = 20)
plt.ylabel("$Volumetric\ Water\ Conten\ (cm^3/cm^3)$", fontsize = 14)
plt.xlabel("$Time\ (days)$", fontsize = 14)
plt.legend(loc = 0) # Positions legend in the best location.
#plt.xlim(0)
plt.ylim(0,30)
plt.text(0.005, 26.3, R_2_value , fontsize = 8, horizontalalignment ='left', verticalalignment ='bottom')
plt.text(0.005, 27.5, RMSE_value , fontsize = 8, horizontalalignment ='left', verticalalignment ='bottom')
plt.text(0.005, 28.5, SSQ , fontsize = 8, horizontalalignment ='left', verticalalignment ='bottom')

## Plotting of the SWCC: Matric Suction Head [cm/H2O] vs. Volumetric Water Content [cm^3/cm^3],
## with optimized van Genuchten fitting parameters: residual volumetric water content (theta_r) [cm^3/cm^3],
## inverse of air entry (alpha) [1/cm], pore size distribution parameter (n), and permeability (K_s) [cm/s].
plt.subplot(1,2,2)
plt.plot(df_SWCC_soil['WC'], df_SWCC_soil['Pressure'], "g", label = "SWCC", alpha = 0.8)
plt.title("$Unsaturated\ Characteristics$", fontsize = 16)
plt.ylabel("$Matric\ Suction\ (cm\ H_2O)$", color = 'green', fontsize = 14)
plt.xlabel("$Volumetric\ Water\ Content\ (cm^3/cm^3)$", fontsize = 14)
plt.legend(loc = 9) # Positions legend in the upper center.
plt.yscale('log')   # Y-axis in log scale.
plt.xticks(rotation = 20)
plt.xlim(0,.40)
plt.ylim(10**-2,10**7)
plt.text(0.005, 4.5*10**5, WCR , fontsize = 8, horizontalalignment ='left', verticalalignment ='bottom')
plt.text(0.005, 1*10**6, ALPHA , fontsize = 8, horizontalalignment ='left', verticalalignment ='bottom')
plt.text(0.005, 2*10**6, N , fontsize = 8, horizontalalignment ='left', verticalalignment ='bottom')
plt.text(0.005, 3.6*10**6, K_SAT , fontsize = 8, horizontalalignment ='left', verticalalignment ='bottom')

## Plotting of the HCF: Unsaturated Hydraulic Conductivity [cm/s] vs. Volumetric Water Content [cm^3/cm^3].
## Plotting on the same graph as the SWCC.
plt.twinx()
plt.plot(df_SWCC_soil['WC'], df_SWCC_soil['Abs K'], ":b", label = "HCF", alpha = 0.8)
plt.ylabel("$K_s\ (cm/s)$", color = 'blue', fontsize = 14)
plt.legend(loc = 1) # Positions legend in the upper right corner.
plt.yscale('log')   # Y-axis in log scale.
plt.xticks(rotation = 20)
plt.ylim(10**-17,1)
plt.tight_layout()
plt.savefig("TRIM Results")
plt.show()

## Plot caption...
print("\nFigures 2 & 3: Objective Function and Unsaturated Characteristics, respectively.", 
      "\n\nObserved & Fitted data are corrected for diffused air; that correction was executed by",
      "Hydrus 1D software.")

## Create a DataFrame to store all the information that are to be exported.
TRIM_results = pd.DataFrame()

## Add all the appropriate data to that DataFrame: data are selected using the sampled points as an index 
## so that the corresponding data for each selected point is collected.
TRIM_results['Pressure'] = df_SWCC_soil['Pressure']              # [cm H2O]
TRIM_results['WC'] = df_SWCC_soil['WC']                          # [cm3/cm3]
TRIM_results['K_sat'] = df_SWCC_soil['Abs K']                    # [cm/s]

## Sets the 'WC' column as the DataFrame index.
TRIM_results = TRIM_results.set_index('WC')

## Export the DataFrame as a csv file.
TRIM_results.to_csv("TRIM_results.csv", sep = "\t")

## Notify the user that the data has been exported to the csv file.
print("\nThe SWCC and HCF data were exported to the csv file: TRIM_results.csv")
print("\nFigure 2 & 3 was saved as TRIM Results.png")
# Out:
# Please specify the path to Hydrus 1D results; the file must be the '\Fit.out' file (e.g., VS_cor-for-diff-air\Fit.out): VS_cor-for-diff-air\Fit.out
# Figures 2 & 3: Objective Function and Unsaturated Characteristics, respectively.
#
# Observed & Fitted data are corrected for diffused air; that correction was executed by Hydrus 1D software.
#
# The SWCC and HCF data were exported to the csv file: TRIM_results.csv

# %% [markdown]
# ___

# %%
pd.read_csv("TRIM_results.csv", sep = "\t")
# Out:
#         WC   Pressure         K_sat
# 0   0.3748       0.00  9.000000e-05
# 1   0.3748       1.41  8.680000e-05
# 2   0.3748       1.68  8.630000e-05
# 3   0.3748       2.00  8.570000e-05
# 4   0.3748       2.37  8.510000e-05
# ..     ...        ...           ...
# 71  0.1261  251000.00  6.060000e-18
# 72  0.1260  298000.00  3.030000e-18
# 73  0.1259  355000.00  1.510000e-18
# 74  0.1259  422000.00  7.540000e-19
# 75  0.1258  501000.00  3.760000e-19
#
# [76 rows x 3 columns]
